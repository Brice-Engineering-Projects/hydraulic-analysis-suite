# %%
from src.models.pipe import Pipe

pipe = Pipe(pipe_material='pvc',
            diameter_in=18.0,
            length_ft=1000.0,
            flow_rate_gpm=4000.0)
print(pipe.c_factor)
# Out:
# 150

# %%
print(pipe.summary())
# Out:
# {'physical_properties': {'flow_rate_gpm': 4000.0, 'diameter_in': 18.0, 'length_ft': 1000.0, 'pipe_material': 'pvc'}, 'hydraulic_properties': {'c_factor': 150, 'roughness_ft': 5e-06, 'manning_n': 0.009}, 'derived_properties': {'diameter_ft': 1.5, 'length_miles': 0.1893939393939394, 'radius_in': 9.0, 'area_sf': 1.7671458676442586, 'volume_cf': 1767.1458676442585, 'flow_rate_cfs': 8.911999999999999, 'velocity_fps': 5.043160365635453}}
