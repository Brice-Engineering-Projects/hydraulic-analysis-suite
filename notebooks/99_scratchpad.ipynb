# %%
from src.models.pipe import Pipe

pipe = Pipe(pipe_material='dip_good',
            diameter_in=36.0,
            length_ft=52000.0,
            flow_rate_gpm=12000.0)
print(pipe.c_factor)
# Out:
# 130

# %%
print(pipe.summary())
# Out:
# {'general_data': {'material_name': 'Ductile Iron Pipe (Good)', 'application': 'pressure', 'category': 'ductile_iron'}, 'physical_properties': {'flow_rate_gpm': 12000.0, 'diameter_in': 36.0, 'length_ft': 52000.0, 'pipe_material': 'dip_good'}, 'hydraulic_properties': {'c_factor': 130, 'roughness_ft': 0.001, 'manning_n': 0.015}, 'derived_properties': {'diameter_ft': 3.0, 'length_miles': 9.848484848484848, 'radius_in': 18.0, 'area_sf': 7.0685834705770345, 'volume_cf': 367566.3404700058, 'flow_rate_cfs': 26.736, 'velocity_fps': 3.78237027422659}}
